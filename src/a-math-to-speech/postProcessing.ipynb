# %%
with open('src/a-math-to-speech/finishedHints.txt', 'r') as file: 
    hints = file.readlines()
    # hints = [hint.strip() for hint in hints]
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 with open('src/a-math-to-speech/finishedHints.txt', 'r') as file:
#       2     hints = file.readlines()
#       3     # hints = [hint.strip() for hint in hints]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'src/a-math-to-speech/finishedHints.txt'

# %%
remove_words = ['cap ','start param', 'end param', 'end fraction'
                ]
